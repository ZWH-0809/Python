# %%
#排队模拟

import simpy
import random
import statistics

#声明从进入电影院到检票完成需要的时间变量
wait_times = []

#建立系统模型，模型可以是许多场景，如银行、检查站、洗车店等，此处为电影院
class Theater(object):
    def __init__(self, env, num_cashiers, num_servers, num_ushers):
        self.env = env
        self.cashier = simpy.Resource(env, num_cashiers)
        self.server = simpy.Resource(env, num_servers)
        self.usher = simpy.Resource(env, num_ushers)
        
    def purchase_ticket(self, moviegoer):
        #根据历史数据，一般购取票平均花费1-2分钟
        yield self.env.timeout(random.randint(1,3))
        
    def check_ticket(self, moviegoer):
        #检票平均需要3秒钟，转为分钟数
        yield self.env.timeout(3/60)
    
    def sell_food(self, moviegoer):
        #购买饮食，平均花费1-5分钟
        yield self.env.timeout(random.randint(1,5))

def go_to_movies(env, moviegoer, theater):
    #观众达到影院的时间
    arrival_time = env.now
    
    #等待购取票 
    with theater.cashier.request() as request:  #观众向收银员请求购票
        yield request    #观众等待收银员完成前面的服务
        yield env.process(theater.purchase_ticket(moviegoer)) 
        
    #请求检票
    with theater.usher.request() as request:
        yield request
        yield env.process(theater.check_ticket(moviegoer))
        
    #不是每一个观众都会购买饮食，这里随机选择是否购买
    if random.choice([True, False]):
        with theater.server.request() as request:
            yield request
            yield env.process(theater.sell_food(moviegoer))
            
    #观众进入会场，前后共计时间
    wait_times.append(env.now - arrival_time)

def run_theater(env, num_cashiers, num_servers, num_ushers):
    theater = Theater(env, num_cashiers, num_servers, num_ushers)
    
    for moviegoer in range(3):#初始化设置，开始有3个观众在等待购取票
        env.process(go_to_movies(env, moviegoer, theater))
        
    while True:
        yield env.timeout(0.20)#此处假设每0.2分钟新增一个观众进入电影院
        
        moviegoer += 1
        env.process(go_to_movies(env, moviegoer, theater))

#定义函数，统计观众平均花费时间，从到达影院到完成检票
def get_average_wait_time(wait_times):
    average_wait = statistics.mean(wait_times)
    #返回等待时间的分秒数，方便查看
    minutes, frac_minutes = divmod(average_wait, 1)
    seconds = frac_minutes * 60
    return round(minutes), round(seconds) 

#创建一个函数，用户可以自主选择员工数量
def get_user_input():
    num_cashiers = input("Input # of cashiers working:")
    num_servers = input("Input # of servers working:")
    num_ushers = input("Input # of ushers working")
    params = [num_cashiers, num_servers, num_ushers]
    if all (str(i).isdigit() for i in params):#Cheack iinput is valid
        params = [int(x) for x in params]
    else:
        print("Could not parse input.The simulation will use default values;",
             "\n1 cashier, 1 server, 1 usher.",
             )
        params = [1,1,1]
    return params

def main():
    #初始化
    random.seed(42)
    num_cashiers, num_servers, num_ushers = get_user_input()
    
    #运行模拟场景
    env = simpy.Environment()
    env.process(run_theater(env, num_cashiers, num_servers, num_ushers))
    env.run(until=90)#假设观众持续入场90分钟
    
    #查看统计结果
    mins, secs = get_average_wait_time(wait_times)
    print(
    "运行程序...",
    f"\n平均等待时间是{mins} 分钟和 {secs} 秒。")

if __name__ == '__main__':
    main()
# Out:
# Input # of cashiers working:100
# Input # of servers working:100
# Input # of ushers working100
# 运行程序...
# 平均等待时间是3 分钟和 29 秒。

# %%
"""
服务站示例
场景介绍:
  一个有特定服务提供工作站，客户服务时长不一，工作机器数有限。
  Client接受服务步骤：Client到达工作站，若有空闲的机器就立刻接受服务，如果没有，就等待直到其他机器空闲下来。
  每个接受过服务的Client都有一个完成满意度（或者为进度）实时统计服务客户数和完成满意进度。
"""
import random
import simpy
 
# 可接受输入参数
RANDOM_SEED = 0         # 不设置
NUM_MACHINES = 2        # 可以同时处理的机器数（类似工作工位数）
TIME_CONSUMING = 5      # 单任务耗时 (可以设计成随机数)
TIME_INTERVAL = 5       # 来车的间隔时间约5分钟   (可以设计成随机数)
SIM_TIME = 1000         # 仿真总时间
CLIENT_NUMBER = 2       # 初始时已经占用机器数
 
 
class WorkStation(object):
    """
    一个工作站，拥有特定数量的机器数。 一个客户首先申请服务。在对应服务时间完成后结束并离开工作站
    """
    def __init__(self, env, num_machines, washtime):
        self.env = env
        self.machine = simpy.Resource(env, num_machines)
        self.washtime = washtime
        self.allClient = 0
        self.accomplishClient = 0
 
    def wash(self, car):
        """服务流程"""
        yield self.env.timeout(random.randint(2, 10))  # 假设服务时间为随机数（2~10）
        self.allClient += 1
        per = random.randint(50, 99)
        print("%s's 任务完成度：%d%%." % (car, per))
        if per > 80:
            self.accomplishClient += 1
 
        print("工作站服务客户数：%d,"
              "工作站服务达标率：%.2f。" % (self.allClient, float(self.accomplishClient) / float(self.allClient)))
 
 
def Client(env, name, cw):
    """
    客户到达动作站接受服务，结束后离开
    """
 
    print('%s 到达工作站 at %.2f.' % (name, env.now))
    with cw.machine.request() as request:
        yield request
        print('%s 接受服务   at %.2f.' % (name, env.now))
        yield env.process(cw.wash(name))
        print('%s 离开服务站 at %.2f.' % (name, env.now))
 
 
def setup(env, num_machines, washtime, t_inter, clientNumber):
    """创建一个工作站，几个初始客户，然后持续有客户到达. 每隔t_inter - 2, t_inter + 3分钟（可以自定义）."""
    # 创建工作站
    workstation = WorkStation(env, num_machines, washtime)
 
    # 创建clientNumber个初始客户
    for i in range(clientNumber):
        env.process(Client(env, 'Client_%d' % i, workstation))
 
    # 在仿真过程中持续创建客户
    while True:
        yield env.timeout(random.randint(t_inter - 2, t_inter + 3))  # 3-8分钟
        i += 1
        env.process(Client(env, 'Client_%d' % i, workstation))
 
 
# 初始化并开始仿真任务
print('开始仿真')
 
# 初始化seed，指定数值的时候方正结果可以复现
random.seed()
 
# 创建一个环境并开始仿真
env = simpy.Environment()
env.process(setup(env, NUM_MACHINES, TIME_CONSUMING, TIME_INTERVAL, CLIENT_NUMBER))
 
# 开始执行!
env.run(until=SIM_TIME)
# Out:
# 开始仿真
# Client_0 到达工作站 at 0.00.
# Client_1 到达工作站 at 0.00.
# Client_0 接受服务   at 0.00.
# Client_1 接受服务   at 0.00.
# Client_2 到达工作站 at 7.00.
# Client_0's 任务完成度：62%.
# 工作站服务客户数：1,工作站服务达标率：0.00。
# Client_1's 任务完成度：90%.
# 工作站服务客户数：2,工作站服务达标率：0.50。
# Client_0 离开服务站 at 10.00.
# Client_1 离开服务站 at 10.00.
# Client_2 接受服务   at 10.00.
# Client_3 到达工作站 at 11.00.
# Client_3 接受服务   at 11.00.
# Client_3's 任务完成度：73%.
# 工作站服务客户数：3,工作站服务达标率：0.33。
# Client_3 离开服务站 at 13.00.
# Client_2's 任务完成度：99%.
# 工作站服务客户数：4,工作站服务达标率：0.50。
# Client_4 到达工作站 at 17.00.
# Client_2 离开服务站 at 17.00.
# Client_4 接受服务   at 17.00.
# Client_5 到达工作站 at 24.00.
# Client_5 接受服务   at 24.00.
# Client_4's 任务完成度：66%.
# 工作站服务客户数：5,工作站服务达标率：0.40。
# Client_4 离开服务站 at 26.00.
# Client_6 到达工作站 at 29.00.
# Client_6 接受服务   at 29.00.
# Client_6's 任务完成度：81%.
# 工作站服务客户数：6,工作站服务达标率：0.50。
# Client_6 离开服务站 at 31.00.
# Client_5's 任务完成度：71%.
# 工作站服务客户数：7,工作站服务达标率：0.43。
# Client_7 到达工作站 at 34.00.
# Client_5 离开服务站 at 34.00.
# Client_7 接受服务   at 34.00.
# Client_7's 任务完成度：65%.
# 工作站服务客户数：8,工作站服务达标率：0.38。
# Client_7 离开服务站 at 39.00.
# Client_8 到达工作站 at 40.00.
# Client_8 接受服务   at 40.00.
# Client_9 到达工作站 at 44.00.
# Client_9 接受服务   at 44.00.
# Client_8's 任务完成度：90%.
# 工作站服务客户数：9,工作站服务达标率：0.44。
# Client_8 离开服务站 at 46.00.
# Client_10 到达工作站 at 50.00.
# Client_10 接受服务   at 50.00.
# Client_9's 任务完成度：52%.
# 工作站服务客户数：10,工作站服务达标率：0.40。
# Client_9 离开服务站 at 52.00.
# Client_11 到达工作站 at 58.00.
# Client_10's 任务完成度：90%.
# 工作站服务客户数：11,工作站服务达标率：0.45。
# Client_11 接受服务   at 58.00.
# Client_10 离开服务站 at 58.00.
# Client_11's 任务完成度：58%.
# 工作站服务客户数：12,工作站服务达标率：0.42。
# Client_11 离开服务站 at 60.00.
# Client_12 到达工作站 at 64.00.
# Client_12 接受服务   at 64.00.
# Client_13 到达工作站 at 68.00.
# Client_13 接受服务   at 68.00.
# Client_12's 任务完成度：69%.
# 工作站服务客户数：13,工作站服务达标率：0.38。
# Client_13's 任务完成度：74%.
# 工作站服务客户数：14,工作站服务达标率：0.36。
# Client_12 离开服务站 at 73.00.
# Client_13 离开服务站 at 73.00.
# Client_14 到达工作站 at 74.00.
# Client_14 接受服务   at 74.00.
# Client_14's 任务完成度：59%.
# 工作站服务客户数：15,工作站服务达标率：0.33。
# Client_14 离开服务站 at 81.00.
# Client_15 到达工作站 at 82.00.
# Client_15 接受服务   at 82.00.
# Client_16 到达工作站 at 86.00.
# Client_16 接受服务   at 86.00.
# Client_17 到达工作站 at 90.00.
# Client_15's 任务完成度：92%.
# 工作站服务客户数：16,工作站服务达标率：0.38。
# Client_16's 任务完成度：59%.
# 工作站服务客户数：17,工作站服务达标率：0.35。
# Client_15 离开服务站 at 92.00.
# Client_16 离开服务站 at 92.00.
# Client_17 接受服务   at 92.00.
# Client_18 到达工作站 at 93.00.
# Client_18 接受服务   at 93.00.
# Client_18's 任务完成度：65%.
# 工作站服务客户数：18,工作站服务达标率：0.33。
# Client_18 离开服务站 at 99.00.
# Client_19 到达工作站 at 100.00.
# Client_19 接受服务   at 100.00.
# Client_17's 任务完成度：64%.
# 工作站服务客户数：19,工作站服务达标率：0.32。
# Client_17 离开服务站 at 102.00.
# Client_20 到达工作站 at 103.00.
# Client_20 接受服务   at 103.00.
# Client_19's 任务完成度：60%.
# 工作站服务客户数：20,工作站服务达标率：0.30。
# Client_19 离开服务站 at 104.00.
# Client_20's 任务完成度：84%.
# 工作站服务客户数：21,工作站服务达标率：0.33。
# Client_20 离开服务站 at 108.00.
# Client_21 到达工作站 at 110.00.
# Client_21 接受服务   at 110.00.
# Client_21's 任务完成度：59%.
# 工作站服务客户数：22,工作站服务达标率：0.32。
# Client_21 离开服务站 at 112.00.
# Client_22 到达工作站 at 113.00.
# Client_22 接受服务   at 113.00.
# Client_23 到达工作站 at 116.00.
# Client_23 接受服务   at 116.00.
# Client_22's 任务完成度：65%.
# 工作站服务客户数：23,工作站服务达标率：0.30。
# Client_22 离开服务站 at 117.00.
# Client_23's 任务完成度：76%.
# 工作站服务客户数：24,工作站服务达标率：0.29。
# Client_23 离开服务站 at 118.00.
# Client_24 到达工作站 at 122.00.
# Client_24 接受服务   at 122.00.
# Client_25 到达工作站 at 125.00.
# Client_25 接受服务   at 125.00.
# Client_24's 任务完成度：62%.
# 工作站服务客户数：25,工作站服务达标率：0.28。
# Client_24 离开服务站 at 127.00.
# Client_26 到达工作站 at 128.00.
# Client_26 接受服务   at 128.00.
# Client_25's 任务完成度：69%.
# 工作站服务客户数：26,工作站服务达标率：0.27。
# Client_25 离开服务站 at 130.00.
# Client_26's 任务完成度：70%.
# 工作站服务客户数：27,工作站服务达标率：0.26。
# Client_26 离开服务站 at 135.00.
# Client_27 到达工作站 at 136.00.
# Client_27 接受服务   at 136.00.
# Client_27's 任务完成度：92%.
# 工作站服务客户数：28,工作站服务达标率：0.29。
# Client_27 离开服务站 at 138.00.
# Client_28 到达工作站 at 140.00.
# Client_28 接受服务   at 140.00.
# Client_28's 任务完成度：62%.
# 工作站服务客户数：29,工作站服务达标率：0.28。
# Client_28 离开服务站 at 143.00.
# Client_29 到达工作站 at 145.00.
# Client_29 接受服务   at 145.00.
# Client_30 到达工作站 at 148.00.
# Client_30 接受服务   at 148.00.
# Client_29's 任务完成度：52%.
# 工作站服务客户数：30,工作站服务达标率：0.27。
# Client_29 离开服务站 at 151.00.
# Client_31 到达工作站 at 153.00.
# Client_30's 任务完成度：88%.
# 工作站服务客户数：31,工作站服务达标率：0.29。
# Client_31 接受服务   at 153.00.
# Client_30 离开服务站 at 153.00.
# Client_32 到达工作站 at 156.00.
# Client_32 接受服务   at 156.00.
# Client_31's 任务完成度：63%.
# 工作站服务客户数：32,工作站服务达标率：0.28。
# Client_31 离开服务站 at 157.00.
# Client_32's 任务完成度：58%.
# 工作站服务客户数：33,工作站服务达标率：0.27。
# Client_32 离开服务站 at 161.00.
# Client_33 到达工作站 at 163.00.
# Client_33 接受服务   at 163.00.
# Client_34 到达工作站 at 166.00.
# Client_34 接受服务   at 166.00.
# Client_33's 任务完成度：82%.
# 工作站服务客户数：34,工作站服务达标率：0.29。
# Client_33 离开服务站 at 167.00.
# Client_35 到达工作站 at 169.00.
# Client_34's 任务完成度：66%.
# 工作站服务客户数：35,工作站服务达标率：0.29。
# Client_35 接受服务   at 169.00.
# Client_34 离开服务站 at 169.00.
# Client_36 到达工作站 at 175.00.
# Client_35's 任务完成度：56%.
# 工作站服务客户数：36,工作站服务达标率：0.28。
# Client_36 接受服务   at 175.00.
# Client_35 离开服务站 at 175.00.
# Client_37 到达工作站 at 182.00.
# Client_37 接受服务   at 182.00.
# Client_36's 任务完成度：85%.
# 工作站服务客户数：37,工作站服务达标率：0.30。
# Client_36 离开服务站 at 185.00.
# Client_37's 任务完成度：68%.
# 工作站服务客户数：38,工作站服务达标率：0.29。
# Client_37 离开服务站 at 187.00.
# Client_38 到达工作站 at 188.00.
# Client_38 接受服务   at 188.00.
# Client_38's 任务完成度：64%.
# 工作站服务客户数：39,工作站服务达标率：0.28。
# Client_38 离开服务站 at 190.00.
# Client_39 到达工作站 at 191.00.
# Client_39 接受服务   at 191.00.
# Client_39's 任务完成度：81%.
# 工作站服务客户数：40,工作站服务达标率：0.30。
# Client_39 离开服务站 at 194.00.
# Client_40 到达工作站 at 195.00.
# Client_40 接受服务   at 195.00.
# Client_41 到达工作站 at 199.00.
# Client_41 接受服务   at 199.00.
# Client_42 到达工作站 at 204.00.
# Client_41's 任务完成度：83%.
# 工作站服务客户数：41,工作站服务达标率：0.32。
# Client_41 离开服务站 at 204.00.
# Client_42 接受服务   at 204.00.
# Client_40's 任务完成度：82%.
# 工作站服务客户数：42,工作站服务达标率：0.33。
# Client_40 离开服务站 at 205.00.
# Client_43 到达工作站 at 208.00.
# Client_43 接受服务   at 208.00.
# Client_42's 任务完成度：85%.
# 工作站服务客户数：43,工作站服务达标率：0.35。
# Client_42 离开服务站 at 212.00.
# Client_44 到达工作站 at 215.00.
# Client_44 接受服务   at 215.00.
# Client_43's 任务完成度：61%.
# 工作站服务客户数：44,工作站服务达标率：0.34。
# Client_43 离开服务站 at 216.00.
# Client_44's 任务完成度：67%.
# 工作站服务客户数：45,工作站服务达标率：0.33。
# Client_44 离开服务站 at 217.00.
# Client_45 到达工作站 at 220.00.
# Client_45 接受服务   at 220.00.
# Client_46 到达工作站 at 225.00.
# Client_46 接受服务   at 225.00.
# Client_45's 任务完成度：98%.
# 工作站服务客户数：46,工作站服务达标率：0.35。
# Client_45 离开服务站 at 226.00.
# Client_47 到达工作站 at 229.00.
# Client_47 接受服务   at 229.00.
# Client_46's 任务完成度：62%.
# 工作站服务客户数：47,工作站服务达标率：0.34。
# Client_46 离开服务站 at 232.00.
# Client_48 到达工作站 at 235.00.
# Client_48 接受服务   at 235.00.
# Client_47's 任务完成度：75%.
# 工作站服务客户数：48,工作站服务达标率：0.33。
# Client_47 离开服务站 at 236.00.
# Client_49 到达工作站 at 240.00.
# Client_49 接受服务   at 240.00.
# Client_48's 任务完成度：63%.
# 工作站服务客户数：49,工作站服务达标率：0.33。
# Client_48 离开服务站 at 241.00.
# Client_50 到达工作站 at 244.00.
# Client_49's 任务完成度：51%.
# 工作站服务客户数：50,工作站服务达标率：0.32。
# Client_50 接受服务   at 244.00.
# Client_49 离开服务站 at 244.00.
# Client_50's 任务完成度：75%.
# 工作站服务客户数：51,工作站服务达标率：0.31。
# Client_50 离开服务站 at 247.00.
# Client_51 到达工作站 at 250.00.
# Client_51 接受服务   at 250.00.
# Client_52 到达工作站 at 254.00.
# Client_52 接受服务   at 254.00.
# Client_51's 任务完成度：97%.
# 工作站服务客户数：52,工作站服务达标率：0.33。
# Client_51 离开服务站 at 255.00.
# Client_53 到达工作站 at 258.00.
# Client_53 接受服务   at 258.00.
# Client_52's 任务完成度：90%.
# 工作站服务客户数：53,工作站服务达标率：0.34。
# Client_52 离开服务站 at 259.00.
# Client_54 到达工作站 at 266.00.
# Client_54 接受服务   at 266.00.
# Client_53's 任务完成度：90%.
# 工作站服务客户数：54,工作站服务达标率：0.35。
# Client_53 离开服务站 at 268.00.
# Client_55 到达工作站 at 273.00.
# Client_55 接受服务   at 273.00.
# Client_55's 任务完成度：67%.
# 工作站服务客户数：55,工作站服务达标率：0.35。
# Client_55 离开服务站 at 275.00.
# Client_54's 任务完成度：89%.
# 工作站服务客户数：56,工作站服务达标率：0.36。
# Client_56 到达工作站 at 276.00.
# Client_54 离开服务站 at 276.00.
# Client_56 接受服务   at 276.00.
# Client_56's 任务完成度：94%.
# 工作站服务客户数：57,工作站服务达标率：0.37。
# Client_56 离开服务站 at 281.00.
# Client_57 到达工作站 at 284.00.
# Client_57 接受服务   at 284.00.
# Client_58 到达工作站 at 288.00.
# Client_58 接受服务   at 288.00.
# Client_57's 任务完成度：75%.
# 工作站服务客户数：58,工作站服务达标率：0.36。
# Client_57 离开服务站 at 289.00.
# Client_59 到达工作站 at 292.00.
# Client_59 接受服务   at 292.00.
# Client_59's 任务完成度：58%.
# 工作站服务客户数：59,工作站服务达标率：0.36。
# Client_59 离开服务站 at 294.00.
# Client_60 到达工作站 at 296.00.
# Client_60 接受服务   at 296.00.
# Client_58's 任务完成度：58%.
# 工作站服务客户数：60,工作站服务达标率：0.35。
# Client_58 离开服务站 at 298.00.
# Client_60's 任务完成度：78%.
# 工作站服务客户数：61,工作站服务达标率：0.34。
# Client_60 离开服务站 at 301.00.
# Client_61 到达工作站 at 304.00.
# Client_61 接受服务   at 304.00.
# Client_62 到达工作站 at 307.00.
# Client_62 接受服务   at 307.00.
# Client_63 到达工作站 at 310.00.
# Client_62's 任务完成度：80%.
# 工作站服务客户数：62,工作站服务达标率：0.34。
# Client_62 离开服务站 at 312.00.
# Client_63 接受服务   at 312.00.
# Client_61's 任务完成度：75%.
# 工作站服务客户数：63,工作站服务达标率：0.33。
# Client_63's 任务完成度：60%.
# 工作站服务客户数：64,工作站服务达标率：0.33。
# Client_61 离开服务站 at 314.00.
# Client_63 离开服务站 at 314.00.
# Client_64 到达工作站 at 318.00.
# Client_64 接受服务   at 318.00.
# Client_64's 任务完成度：95%.
# 工作站服务客户数：65,工作站服务达标率：0.34。
# Client_64 离开服务站 at 320.00.
# Client_65 到达工作站 at 326.00.
# Client_65 接受服务   at 326.00.
# Client_66 到达工作站 at 332.00.
# Client_66 接受服务   at 332.00.
# Client_65's 任务完成度：74%.
# 工作站服务客户数：66,工作站服务达标率：0.33。
# Client_65 离开服务站 at 333.00.
# Client_67 到达工作站 at 338.00.
# Client_67 接受服务   at 338.00.
# Client_66's 任务完成度：71%.
# 工作站服务客户数：67,工作站服务达标率：0.33。
# Client_66 离开服务站 at 340.00.
# Client_68 到达工作站 at 346.00.
# Client_68 接受服务   at 346.00.
# Client_67's 任务完成度：84%.
# 工作站服务客户数：68,工作站服务达标率：0.34。
# Client_67 离开服务站 at 347.00.
# Client_69 到达工作站 at 349.00.
# Client_69 接受服务   at 349.00.
# Client_70 到达工作站 at 354.00.
# Client_68's 任务完成度：83%.
# 工作站服务客户数：69,工作站服务达标率：0.35。
# Client_68 离开服务站 at 356.00.
# Client_70 接受服务   at 356.00.
# Client_69's 任务完成度：63%.
# 工作站服务客户数：70,工作站服务达标率：0.34。
# Client_69 离开服务站 at 359.00.
# Client_71 到达工作站 at 360.00.
# Client_71 接受服务   at 360.00.
# Client_70's 任务完成度：92%.
# 工作站服务客户数：71,工作站服务达标率：0.35。
# Client_70 离开服务站 at 362.00.
# Client_71's 任务完成度：51%.
# 工作站服务客户数：72,工作站服务达标率：0.35。
# Client_71 离开服务站 at 364.00.
# Client_72 到达工作站 at 365.00.
# Client_72 接受服务   at 365.00.
# Client_72's 任务完成度：70%.
# 工作站服务客户数：73,工作站服务达标率：0.34。
# Client_72 离开服务站 at 368.00.
# Client_73 到达工作站 at 372.00.
# Client_73 接受服务   at 372.00.
# Client_73's 任务完成度：78%.
# 工作站服务客户数：74,工作站服务达标率：0.34。
# Client_73 离开服务站 at 375.00.
# Client_74 到达工作站 at 377.00.
# Client_74 接受服务   at 377.00.
# Client_74's 任务完成度：54%.
# 工作站服务客户数：75,工作站服务达标率：0.33。
# Client_74 离开服务站 at 379.00.
# Client_75 到达工作站 at 385.00.
# Client_75 接受服务   at 385.00.
# Client_75's 任务完成度：65%.
# 工作站服务客户数：76,工作站服务达标率：0.33。
# Client_75 离开服务站 at 388.00.
# Client_76 到达工作站 at 393.00.
# Client_76 接受服务   at 393.00.
# Client_77 到达工作站 at 396.00.
# Client_77 接受服务   at 396.00.
# Client_76's 任务完成度：65%.
# 工作站服务客户数：77,工作站服务达标率：0.32。
# Client_78 到达工作站 at 403.00.
# Client_76 离开服务站 at 403.00.
# Client_78 接受服务   at 403.00.
# Client_77's 任务完成度：91%.
# 工作站服务客户数：78,工作站服务达标率：0.33。
# Client_77 离开服务站 at 406.00.
# Client_79 到达工作站 at 410.00.
# Client_79 接受服务   at 410.00.
# Client_78's 任务完成度：76%.
# 工作站服务客户数：79,工作站服务达标率：0.33。
# Client_78 离开服务站 at 413.00.
# Client_79's 任务完成度：97%.
# 工作站服务客户数：80,工作站服务达标率：0.34。
# Client_79 离开服务站 at 415.00.
# Client_80 到达工作站 at 417.00.
# Client_80 接受服务   at 417.00.
# Client_81 到达工作站 at 423.00.
# Client_80's 任务完成度：59%.
# 工作站服务客户数：81,工作站服务达标率：0.33。
# Client_81 接受服务   at 423.00.
# Client_80 离开服务站 at 423.00.
# Client_81's 任务完成度：81%.
# 工作站服务客户数：82,工作站服务达标率：0.34。
# Client_81 离开服务站 at 425.00.
# Client_82 到达工作站 at 427.00.
# Client_82 接受服务   at 427.00.
# Client_82's 任务完成度：55%.
# 工作站服务客户数：83,工作站服务达标率：0.34。
# Client_82 离开服务站 at 429.00.
# Client_83 到达工作站 at 434.00.
# Client_83 接受服务   at 434.00.
# Client_84 到达工作站 at 441.00.
# Client_84 接受服务   at 441.00.
# Client_83's 任务完成度：74%.
# 工作站服务客户数：84,工作站服务达标率：0.33。
# Client_83 离开服务站 at 443.00.
# Client_84's 任务完成度：98%.
# 工作站服务客户数：85,工作站服务达标率：0.34。
# Client_84 离开服务站 at 447.00.
# Client_85 到达工作站 at 449.00.
# Client_85 接受服务   at 449.00.
# Client_86 到达工作站 at 452.00.
# Client_86 接受服务   at 452.00.
# Client_85's 任务完成度：94%.
# 工作站服务客户数：86,工作站服务达标率：0.35。
# Client_87 到达工作站 at 455.00.
# Client_85 离开服务站 at 455.00.
# Client_87 接受服务   at 455.00.
# Client_86's 任务完成度：55%.
# 工作站服务客户数：87,工作站服务达标率：0.34。
# Client_88 到达工作站 at 461.00.
# Client_86 离开服务站 at 461.00.
# Client_88 接受服务   at 461.00.
# Client_87's 任务完成度：64%.
# 工作站服务客户数：88,工作站服务达标率：0.34。
# Client_87 离开服务站 at 463.00.
# Client_89 到达工作站 at 467.00.
# Client_89 接受服务   at 467.00.
# Client_88's 任务完成度：70%.
# 工作站服务客户数：89,工作站服务达标率：0.34。
# Client_88 离开服务站 at 469.00.
# Client_90 到达工作站 at 470.00.
# Client_90 接受服务   at 470.00.
# Client_89's 任务完成度：70%.
# 工作站服务客户数：90,工作站服务达标率：0.33。
# Client_89 离开服务站 at 472.00.
# Client_91 到达工作站 at 473.00.
# Client_91 接受服务   at 473.00.
# Client_91's 任务完成度：87%.
# 工作站服务客户数：91,工作站服务达标率：0.34。
# Client_91 离开服务站 at 478.00.
# Client_92 到达工作站 at 479.00.
# Client_92 接受服务   at 479.00.
# Client_90's 任务完成度：69%.
# 工作站服务客户数：92,工作站服务达标率：0.34。
# Client_90 离开服务站 at 480.00.
# Client_92's 任务完成度：60%.
# 工作站服务客户数：93,工作站服务达标率：0.33。
# Client_92 离开服务站 at 483.00.
# Client_93 到达工作站 at 486.00.
# Client_93 接受服务   at 486.00.
# Client_94 到达工作站 at 489.00.
# Client_94 接受服务   at 489.00.
# Client_95 到达工作站 at 495.00.
# Client_94's 任务完成度：90%.
# 工作站服务客户数：94,工作站服务达标率：0.34。
# Client_94 离开服务站 at 495.00.
# Client_95 接受服务   at 495.00.
# Client_93's 任务完成度：54%.
# 工作站服务客户数：95,工作站服务达标率：0.34。
# Client_93 离开服务站 at 496.00.
# Client_96 到达工作站 at 501.00.
# Client_96 接受服务   at 501.00.
# Client_95's 任务完成度：84%.
# 工作站服务客户数：96,工作站服务达标率：0.34。
# Client_97 到达工作站 at 504.00.
# Client_95 离开服务站 at 504.00.
# Client_97 接受服务   at 504.00.
# Client_97's 任务完成度：57%.
# 工作站服务客户数：97,工作站服务达标率：0.34。
# Client_97 离开服务站 at 507.00.
# Client_98 到达工作站 at 508.00.
# Client_98 接受服务   at 508.00.
# Client_96's 任务完成度：73%.
# 工作站服务客户数：98,工作站服务达标率：0.34。
# Client_99 到达工作站 at 511.00.
# Client_96 离开服务站 at 511.00.
# Client_99 接受服务   at 511.00.
# Client_99's 任务完成度：77%.
# 工作站服务客户数：99,工作站服务达标率：0.33。
# Client_99 离开服务站 at 513.00.
# Client_98's 任务完成度：75%.
# 工作站服务客户数：100,工作站服务达标率：0.33。
# Client_98 离开服务站 at 518.00.
# Client_100 到达工作站 at 519.00.
# Client_100 接受服务   at 519.00.
# Client_100's 任务完成度：97%.
# 工作站服务客户数：101,工作站服务达标率：0.34。
# Client_100 离开服务站 at 522.00.
# Client_101 到达工作站 at 523.00.
# Client_101 接受服务   at 523.00.
# Client_102 到达工作站 at 530.00.
# Client_102 接受服务   at 530.00.
# Client_101's 任务完成度：51%.
# 工作站服务客户数：102,工作站服务达标率：0.33。
# Client_101 离开服务站 at 531.00.
# Client_103 到达工作站 at 533.00.
# Client_103 接受服务   at 533.00.
# Client_104 到达工作站 at 537.00.
# Client_103's 任务完成度：61%.
# 工作站服务客户数：103,工作站服务达标率：0.33。
# Client_103 离开服务站 at 539.00.
# Client_104 接受服务   at 539.00.
# Client_102's 任务完成度：77%.
# 工作站服务客户数：104,工作站服务达标率：0.33。
# Client_102 离开服务站 at 540.00.
# Client_105 到达工作站 at 541.00.
# Client_105 接受服务   at 541.00.
# Client_104's 任务完成度：98%.
# 工作站服务客户数：105,工作站服务达标率：0.33。
# Client_104 离开服务站 at 542.00.
# Client_106 到达工作站 at 545.00.
# Client_106 接受服务   at 545.00.
# Client_106's 任务完成度：50%.
# 工作站服务客户数：106,工作站服务达标率：0.33。
# Client_106 离开服务站 at 548.00.
# Client_105's 任务完成度：70%.
# 工作站服务客户数：107,工作站服务达标率：0.33。
# Client_105 离开服务站 at 551.00.
# Client_107 到达工作站 at 553.00.
# Client_107 接受服务   at 553.00.
# Client_108 到达工作站 at 559.00.
# Client_108 接受服务   at 559.00.
# Client_107's 任务完成度：57%.
# 工作站服务客户数：108,工作站服务达标率：0.32。
# Client_107 离开服务站 at 562.00.
# Client_109 到达工作站 at 565.00.
# Client_108's 任务完成度：79%.
# 工作站服务客户数：109,工作站服务达标率：0.32。
# Client_109 接受服务   at 565.00.
# Client_108 离开服务站 at 565.00.
# Client_110 到达工作站 at 571.00.
# Client_110 接受服务   at 571.00.
# Client_109's 任务完成度：54%.
# 工作站服务客户数：110,工作站服务达标率：0.32。
# Client_111 到达工作站 at 574.00.
# Client_110's 任务完成度：59%.
# 工作站服务客户数：111,工作站服务达标率：0.32。
# Client_109 离开服务站 at 574.00.
# Client_110 离开服务站 at 574.00.
# Client_111 接受服务   at 574.00.
# Client_112 到达工作站 at 581.00.
# Client_112 接受服务   at 581.00.
# Client_111's 任务完成度：53%.
# 工作站服务客户数：112,工作站服务达标率：0.31。
# Client_111 离开服务站 at 584.00.
# Client_113 到达工作站 at 585.00.
# Client_113 接受服务   at 585.00.
# Client_112's 任务完成度：70%.
# 工作站服务客户数：113,工作站服务达标率：0.31。
# Client_113's 任务完成度：75%.
# 工作站服务客户数：114,工作站服务达标率：0.31。
# Client_112 离开服务站 at 589.00.
# Client_113 离开服务站 at 589.00.
# Client_114 到达工作站 at 591.00.
# Client_114 接受服务   at 591.00.
# Client_114's 任务完成度：90%.
# 工作站服务客户数：115,工作站服务达标率：0.31。
# Client_114 离开服务站 at 596.00.
# Client_115 到达工作站 at 597.00.
# Client_115 接受服务   at 597.00.
# Client_115's 任务完成度：59%.
# 工作站服务客户数：116,工作站服务达标率：0.31。
# Client_115 离开服务站 at 603.00.
# Client_116 到达工作站 at 604.00.
# Client_116 接受服务   at 604.00.
# Client_117 到达工作站 at 611.00.
# Client_117 接受服务   at 611.00.
# Client_116's 任务完成度：82%.
# 工作站服务客户数：117,工作站服务达标率：0.32。
# Client_118 到达工作站 at 614.00.
# Client_117's 任务完成度：73%.
# 工作站服务客户数：118,工作站服务达标率：0.31。
# Client_116 离开服务站 at 614.00.
# Client_117 离开服务站 at 614.00.
# Client_118 接受服务   at 614.00.
# Client_119 到达工作站 at 618.00.
# Client_119 接受服务   at 618.00.
# Client_119's 任务完成度：71%.
# 工作站服务客户数：119,工作站服务达标率：0.31。
# Client_119 离开服务站 at 621.00.
# Client_118's 任务完成度：92%.
# 工作站服务客户数：120,工作站服务达标率：0.32。
# Client_118 离开服务站 at 622.00.
# Client_120 到达工作站 at 626.00.
# Client_120 接受服务   at 626.00.
# Client_121 到达工作站 at 630.00.
# Client_120's 任务完成度：62%.
# 工作站服务客户数：121,工作站服务达标率：0.31。
# Client_121 接受服务   at 630.00.
# Client_120 离开服务站 at 630.00.
# Client_122 到达工作站 at 633.00.
# Client_122 接受服务   at 633.00.
# Client_121's 任务完成度：96%.
# 工作站服务客户数：122,工作站服务达标率：0.32。
# Client_121 离开服务站 at 635.00.
# Client_123 到达工作站 at 638.00.
# Client_122's 任务完成度：90%.
# 工作站服务客户数：123,工作站服务达标率：0.33。
# Client_123 接受服务   at 638.00.
# Client_122 离开服务站 at 638.00.
# Client_124 到达工作站 at 642.00.
# Client_124 接受服务   at 642.00.
# Client_123's 任务完成度：64%.
# 工作站服务客户数：124,工作站服务达标率：0.32。
# Client_123 离开服务站 at 643.00.
# Client_125 到达工作站 at 645.00.
# Client_124's 任务完成度：69%.
# 工作站服务客户数：125,工作站服务达标率：0.32。
# Client_125 接受服务   at 645.00.
# Client_124 离开服务站 at 645.00.
# Client_126 到达工作站 at 648.00.
# Client_126 接受服务   at 648.00.
# Client_125's 任务完成度：87%.
# 工作站服务客户数：126,工作站服务达标率：0.33。
# Client_125 离开服务站 at 652.00.
# Client_127 到达工作站 at 653.00.
# Client_127 接受服务   at 653.00.
# Client_126's 任务完成度：86%.
# 工作站服务客户数：127,工作站服务达标率：0.33。
# Client_127's 任务完成度：55%.
# 工作站服务客户数：128,工作站服务达标率：0.33。
# Client_126 离开服务站 at 657.00.
# Client_127 离开服务站 at 657.00.
# Client_128 到达工作站 at 661.00.
# Client_128 接受服务   at 661.00.
# Client_128's 任务完成度：65%.
# 工作站服务客户数：129,工作站服务达标率：0.33。
# Client_128 离开服务站 at 663.00.
# Client_129 到达工作站 at 665.00.
# Client_129 接受服务   at 665.00.
# Client_130 到达工作站 at 669.00.
# Client_130 接受服务   at 669.00.
# Client_131 到达工作站 at 673.00.
# Client_129's 任务完成度：50%.
# 工作站服务客户数：130,工作站服务达标率：0.32。
# Client_129 离开服务站 at 674.00.
# Client_131 接受服务   at 674.00.
# Client_131's 任务完成度：89%.
# 工作站服务客户数：131,工作站服务达标率：0.33。
# Client_131 离开服务站 at 676.00.
# Client_130's 任务完成度：79%.
# 工作站服务客户数：132,工作站服务达标率：0.33。
# Client_130 离开服务站 at 678.00.
# Client_132 到达工作站 at 681.00.
# Client_132 接受服务   at 681.00.
# Client_133 到达工作站 at 685.00.
# Client_133 接受服务   at 685.00.
# Client_134 到达工作站 at 689.00.
# Client_132's 任务完成度：88%.
# 工作站服务客户数：133,工作站服务达标率：0.33。
# Client_132 离开服务站 at 691.00.
# Client_134 接受服务   at 691.00.
# Client_135 到达工作站 at 692.00.
# Client_133's 任务完成度：77%.
# 工作站服务客户数：134,工作站服务达标率：0.33。
# Client_133 离开服务站 at 695.00.
# Client_135 接受服务   at 695.00.
# Client_136 到达工作站 at 697.00.
# Client_134's 任务完成度：56%.
# 工作站服务客户数：135,工作站服务达标率：0.33。
# Client_135's 任务完成度：85%.
# 工作站服务客户数：136,工作站服务达标率：0.33。
# Client_134 离开服务站 at 701.00.
# Client_135 离开服务站 at 701.00.
# Client_136 接受服务   at 701.00.
# Client_137 到达工作站 at 702.00.
# Client_137 接受服务   at 702.00.
# Client_136's 任务完成度：77%.
# 工作站服务客户数：137,工作站服务达标率：0.33。
# Client_136 离开服务站 at 704.00.
# Client_138 到达工作站 at 706.00.
# Client_138 接受服务   at 706.00.
# Client_137's 任务完成度：56%.
# 工作站服务客户数：138,工作站服务达标率：0.33。
# Client_137 离开服务站 at 708.00.
# Client_138's 任务完成度：61%.
# 工作站服务客户数：139,工作站服务达标率：0.32。
# Client_138 离开服务站 at 709.00.
# Client_139 到达工作站 at 710.00.
# Client_139 接受服务   at 710.00.
# Client_139's 任务完成度：63%.
# 工作站服务客户数：140,工作站服务达标率：0.32。
# Client_139 离开服务站 at 715.00.
# Client_140 到达工作站 at 716.00.
# Client_140 接受服务   at 716.00.
# Client_141 到达工作站 at 723.00.
# Client_140's 任务完成度：93%.
# 工作站服务客户数：141,工作站服务达标率：0.33。
# Client_141 接受服务   at 723.00.
# Client_140 离开服务站 at 723.00.
# Client_142 到达工作站 at 728.00.
# Client_142 接受服务   at 728.00.
# Client_141's 任务完成度：91%.
# 工作站服务客户数：142,工作站服务达标率：0.33。
# Client_142's 任务完成度：95%.
# 工作站服务客户数：143,工作站服务达标率：0.34。
# Client_141 离开服务站 at 730.00.
# Client_142 离开服务站 at 730.00.
# Client_143 到达工作站 at 735.00.
# Client_143 接受服务   at 735.00.
# Client_143's 任务完成度：52%.
# 工作站服务客户数：144,工作站服务达标率：0.33。
# Client_143 离开服务站 at 739.00.
# Client_144 到达工作站 at 742.00.
# Client_144 接受服务   at 742.00.
# Client_145 到达工作站 at 746.00.
# Client_145 接受服务   at 746.00.
# Client_144's 任务完成度：98%.
# 工作站服务客户数：145,工作站服务达标率：0.34。
# Client_144 离开服务站 at 749.00.
# Client_146 到达工作站 at 753.00.
# Client_146 接受服务   at 753.00.
# Client_145's 任务完成度：57%.
# 工作站服务客户数：146,工作站服务达标率：0.34。
# Client_145 离开服务站 at 754.00.
# Client_147 到达工作站 at 756.00.
# Client_146's 任务完成度：72%.
# 工作站服务客户数：147,工作站服务达标率：0.33。
# Client_147 接受服务   at 756.00.
# Client_146 离开服务站 at 756.00.
# Client_148 到达工作站 at 761.00.
# Client_148 接受服务   at 761.00.
# Client_148's 任务完成度：99%.
# 工作站服务客户数：148,工作站服务达标率：0.34。
# Client_148 离开服务站 at 763.00.
# Client_147's 任务完成度：82%.
# 工作站服务客户数：149,工作站服务达标率：0.34。
# Client_149 到达工作站 at 766.00.
# Client_147 离开服务站 at 766.00.
# Client_149 接受服务   at 766.00.
# Client_150 到达工作站 at 772.00.
# Client_150 接受服务   at 772.00.
# Client_149's 任务完成度：65%.
# 工作站服务客户数：150,工作站服务达标率：0.34。
# Client_149 离开服务站 at 773.00.
# Client_151 到达工作站 at 778.00.
# Client_150's 任务完成度：88%.
# 工作站服务客户数：151,工作站服务达标率：0.34。
# Client_151 接受服务   at 778.00.
# Client_150 离开服务站 at 778.00.
# Client_152 到达工作站 at 786.00.
# Client_151's 任务完成度：93%.
# 工作站服务客户数：152,工作站服务达标率：0.35。
# Client_152 接受服务   at 786.00.
# Client_151 离开服务站 at 786.00.
# Client_153 到达工作站 at 789.00.
# Client_153 接受服务   at 789.00.
# Client_154 到达工作站 at 793.00.
# Client_153's 任务完成度：73%.
# 工作站服务客户数：153,工作站服务达标率：0.35。
# Client_153 离开服务站 at 794.00.
# Client_154 接受服务   at 794.00.
# Client_152's 任务完成度：64%.
# 工作站服务客户数：154,工作站服务达标率：0.34。
# Client_154's 任务完成度：63%.
# 工作站服务客户数：155,工作站服务达标率：0.34。
# Client_152 离开服务站 at 796.00.
# Client_154 离开服务站 at 796.00.
# Client_155 到达工作站 at 799.00.
# Client_155 接受服务   at 799.00.
# Client_156 到达工作站 at 803.00.
# Client_155's 任务完成度：55%.
# 工作站服务客户数：156,工作站服务达标率：0.34。
# Client_156 接受服务   at 803.00.
# Client_155 离开服务站 at 803.00.
# Client_156's 任务完成度：77%.
# 工作站服务客户数：157,工作站服务达标率：0.34。
# Client_156 离开服务站 at 805.00.
# Client_157 到达工作站 at 806.00.
# Client_157 接受服务   at 806.00.
# Client_158 到达工作站 at 811.00.
# Client_158 接受服务   at 811.00.
# Client_157's 任务完成度：74%.
# 工作站服务客户数：158,工作站服务达标率：0.34。
# Client_157 离开服务站 at 815.00.
# Client_158's 任务完成度：64%.
# 工作站服务客户数：159,工作站服务达标率：0.33。
# Client_158 离开服务站 at 816.00.
# Client_159 到达工作站 at 819.00.
# Client_159 接受服务   at 819.00.
# Client_160 到达工作站 at 827.00.
# Client_160 接受服务   at 827.00.
# Client_159's 任务完成度：61%.
# 工作站服务客户数：160,工作站服务达标率：0.33。
# Client_159 离开服务站 at 829.00.
# Client_161 到达工作站 at 832.00.
# Client_161 接受服务   at 832.00.
# Client_160's 任务完成度：65%.
# 工作站服务客户数：161,工作站服务达标率：0.33。
# Client_160 离开服务站 at 834.00.
# Client_162 到达工作站 at 835.00.
# Client_162 接受服务   at 835.00.
# Client_162's 任务完成度：94%.
# 工作站服务客户数：162,工作站服务达标率：0.33。
# Client_162 离开服务站 at 837.00.
# Client_161's 任务完成度：99%.
# 工作站服务客户数：163,工作站服务达标率：0.34。
# Client_161 离开服务站 at 840.00.
# Client_163 到达工作站 at 843.00.
# Client_163 接受服务   at 843.00.
# Client_163's 任务完成度：93%.
# 工作站服务客户数：164,工作站服务达标率：0.34。
# Client_163 离开服务站 at 846.00.
# Client_164 到达工作站 at 848.00.
# Client_164 接受服务   at 848.00.
# Client_165 到达工作站 at 851.00.
# Client_165 接受服务   at 851.00.
# Client_165's 任务完成度：53%.
# 工作站服务客户数：165,工作站服务达标率：0.34。
# Client_165 离开服务站 at 855.00.
# Client_164's 任务完成度：74%.
# 工作站服务客户数：166,工作站服务达标率：0.34。
# Client_164 离开服务站 at 857.00.
# Client_166 到达工作站 at 859.00.
# Client_166 接受服务   at 859.00.
# Client_167 到达工作站 at 864.00.
# Client_166's 任务完成度：59%.
# 工作站服务客户数：167,工作站服务达标率：0.34。
# Client_167 接受服务   at 864.00.
# Client_166 离开服务站 at 864.00.
# Client_167's 任务完成度：89%.
# 工作站服务客户数：168,工作站服务达标率：0.34。
# Client_167 离开服务站 at 868.00.
# Client_168 到达工作站 at 871.00.
# Client_168 接受服务   at 871.00.
# Client_169 到达工作站 at 876.00.
# Client_169 接受服务   at 876.00.
# Client_170 到达工作站 at 880.00.
# Client_168's 任务完成度：80%.
# 工作站服务客户数：169,工作站服务达标率：0.34。
# Client_169's 任务完成度：85%.
# 工作站服务客户数：170,工作站服务达标率：0.34。
# Client_168 离开服务站 at 881.00.
# Client_169 离开服务站 at 881.00.
# Client_170 接受服务   at 881.00.
# Client_171 到达工作站 at 885.00.
# Client_170's 任务完成度：83%.
# 工作站服务客户数：171,工作站服务达标率：0.35。
# Client_171 接受服务   at 885.00.
# Client_170 离开服务站 at 885.00.
# Client_172 到达工作站 at 892.00.
# Client_172 接受服务   at 892.00.
# Client_171's 任务完成度：61%.
# 工作站服务客户数：172,工作站服务达标率：0.34。
# Client_171 离开服务站 at 895.00.
# Client_173 到达工作站 at 897.00.
# Client_173 接受服务   at 897.00.
# Client_174 到达工作站 at 900.00.
# Client_172's 任务完成度：64%.
# 工作站服务客户数：173,工作站服务达标率：0.34。
# Client_172 离开服务站 at 901.00.
# Client_174 接受服务   at 901.00.
# Client_173's 任务完成度：57%.
# 工作站服务客户数：174,工作站服务达标率：0.34。
# Client_173 离开服务站 at 907.00.
# Client_175 到达工作站 at 908.00.
# Client_174's 任务完成度：81%.
# 工作站服务客户数：175,工作站服务达标率：0.34。
# Client_175 接受服务   at 908.00.
# Client_174 离开服务站 at 908.00.
# Client_176 到达工作站 at 913.00.
# Client_176 接受服务   at 913.00.
# Client_175's 任务完成度：60%.
# 工作站服务客户数：176,工作站服务达标率：0.34。
# Client_175 离开服务站 at 915.00.
# Client_177 到达工作站 at 920.00.
# Client_177 接受服务   at 920.00.
# Client_176's 任务完成度：65%.
# 工作站服务客户数：177,工作站服务达标率：0.34。
# Client_176 离开服务站 at 921.00.
# Client_177's 任务完成度：96%.
# 工作站服务客户数：178,工作站服务达标率：0.34。
# Client_177 离开服务站 at 922.00.
# Client_178 到达工作站 at 925.00.
# Client_178 接受服务   at 925.00.
# Client_179 到达工作站 at 928.00.
# Client_179 接受服务   at 928.00.
# Client_179's 任务完成度：95%.
# 工作站服务客户数：179,工作站服务达标率：0.35。
# Client_179 离开服务站 at 931.00.
# Client_180 到达工作站 at 932.00.
# Client_180 接受服务   at 932.00.
# Client_178's 任务完成度：62%.
# 工作站服务客户数：180,工作站服务达标率：0.34。
# Client_178 离开服务站 at 934.00.
# Client_181 到达工作站 at 937.00.
# Client_181 接受服务   at 937.00.
# Client_180's 任务完成度：89%.
# 工作站服务客户数：181,工作站服务达标率：0.35。
# Client_180 离开服务站 at 942.00.
# Client_182 到达工作站 at 943.00.
# Client_182 接受服务   at 943.00.
# Client_181's 任务完成度：63%.
# 工作站服务客户数：182,工作站服务达标率：0.35。
# Client_181 离开服务站 at 946.00.
# Client_182's 任务完成度：90%.
# 工作站服务客户数：183,工作站服务达标率：0.35。
# Client_182 离开服务站 at 949.00.
# Client_183 到达工作站 at 950.00.
# Client_183 接受服务   at 950.00.
# Client_184 到达工作站 at 957.00.
# Client_184 接受服务   at 957.00.
# Client_183's 任务完成度：91%.
# 工作站服务客户数：184,工作站服务达标率：0.35。
# Client_183 离开服务站 at 959.00.
# Client_185 到达工作站 at 965.00.
# Client_185 接受服务   at 965.00.
# Client_184's 任务完成度：64%.
# 工作站服务客户数：185,工作站服务达标率：0.35。
# Client_184 离开服务站 at 966.00.
# Client_185's 任务完成度：86%.
# 工作站服务客户数：186,工作站服务达标率：0.35。
# Client_185 离开服务站 at 970.00.
# Client_186 到达工作站 at 972.00.
# Client_186 接受服务   at 972.00.
# Client_187 到达工作站 at 975.00.
# Client_187 接受服务   at 975.00.
# Client_186's 任务完成度：61%.
# 工作站服务客户数：187,工作站服务达标率：0.35。
# Client_186 离开服务站 at 978.00.
# Client_187's 任务完成度：62%.
# 工作站服务客户数：188,工作站服务达标率：0.35。
# Client_187 离开服务站 at 982.00.
# Client_188 到达工作站 at 983.00.
# Client_188 接受服务   at 983.00.
# Client_188's 任务完成度：76%.
# 工作站服务客户数：189,工作站服务达标率：0.35。
# Client_188 离开服务站 at 988.00.
# Client_189 到达工作站 at 990.00.
# Client_189 接受服务   at 990.00.
# Client_190 到达工作站 at 993.00.
# Client_190 接受服务   at 993.00.
# Client_189's 任务完成度：93%.
# 工作站服务客户数：190,工作站服务达标率：0.35。
# Client_191 到达工作站 at 996.00.
# Client_189 离开服务站 at 996.00.
# Client_191 接受服务   at 996.00.
# Client_190's 任务完成度：72%.
# 工作站服务客户数：191,工作站服务达标率：0.35。
# Client_190 离开服务站 at 998.00.
# Client_191's 任务完成度：67%.
# 工作站服务客户数：192,工作站服务达标率：0.35。
# Client_191 离开服务站 at 999.00.

# %%
#example1

import simpy
def car(env):#定义汽车进程生成器 传入环境实例env
    while True:
        print('Start parking at %d' % env.now)
        parking_duration = 5
        yield env.timeout(parking_duration)#被挂起并等待超时执行
 
        print('Start driving at %d' % env.now)
        trip_duration = 2
        yield env.timeout(trip_duration)
        
env = simpy.Environment()#声明环境实例
env.process(car(env))#传入进程
env.run(until=15)#进程开始
# Out:
# Start parking at 0
# Start driving at 5
# Start parking at 7
# Start driving at 12
# Start parking at 14

# %%
#引入资源概念

import simpy
env = simpy.Environment()
bcs = simpy.Resource(env, capacity=2)#实例化两个资源

def car(env, name, bcs, driving_time, charge_duration):
    # 模拟驶向充电站
    yield env.timeout(driving_time)
 
    # 请求充点桩
    print('%s 到达时间： %d' % (name, env.now))
    with bcs.request() as req:
        yield req
 
        # 充点进程
        print('%s 充点开始时间： %s' % (name, env.now))
        yield env.timeout(charge_duration)
        print('%s 驶离时间： %s' % (name, env.now))

#创建汽车进程        
for i in range(4):
    env.process(car(env, '第 %d 辆汽车 ' % (i+1), bcs, i*2, 5))

env.run()
# Out:
# 第 1 辆汽车  到达时间： 0
# 第 1 辆汽车  充点开始时间： 0
# 第 2 辆汽车  到达时间： 2
# 第 2 辆汽车  充点开始时间： 2
# 第 3 辆汽车  到达时间： 4
# 第 1 辆汽车  驶离时间： 5
# 第 3 辆汽车  充点开始时间： 5
# 第 4 辆汽车  到达时间： 6
# 第 2 辆汽车  驶离时间： 7
# 第 4 辆汽车  充点开始时间： 7
# 第 3 辆汽车  驶离时间： 10
# 第 4 辆汽车  驶离时间： 12
